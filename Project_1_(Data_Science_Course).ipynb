# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import scipy as sp
from pymystem3 import Mystem
import re
from collections import Counter

# %%
data = pd.read_csv('C:/Users/atche/data.csv')
data.head()
# Out:
#    children  days_employed  dob_years education  education_id  \
# 0         1   -8437.673028         42    высшее             0
# 1         1   -4024.803754         36   среднее             1
# 2         0   -5623.422610         33   Среднее             1
# 3         3   -4124.747207         32   среднее             1
# 4         0  340266.072047         53   среднее             1
#
#       family_status  family_status_id gender income_type  debt   total_income  \
# 0   женат / замужем                 0      F   сотрудник     0  253875.639453
# 1   женат / замужем                 0      F   сотрудник     0  112080.014102
# 2   женат / замужем                 0      M   сотрудник     0  145885.952297
# 3   женат / замужем                 0      M   сотрудник     0  267628.550329
# 4  гражданский брак                 1      F   пенсионер     0  158616.077870
#
#                       purpose
# 0               покупка жилья
# 1     приобретение автомобиля
# 2               покупка жилья
# 3  дополнительное образование
# 4             сыграть свадьбу

# %% [markdown]
# Сведения об используемой памяти

# %%
data.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21525 entries, 0 to 21524
# Data columns (total 12 columns):
# children            21525 non-null int64
# days_employed       19351 non-null float64
# dob_years           21525 non-null int64
# education           21525 non-null object
# education_id        21525 non-null int64
# family_status       21525 non-null object
# family_status_id    21525 non-null int64
# gender              21525 non-null object
# income_type         21525 non-null object
# debt                21525 non-null int64
# total_income        19351 non-null float64
# purpose             21525 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 11.4 MB

# %%
for dtype in ['float64','int64','object']:
    selected_dtype = data.select_dtypes(include=[dtype])
    mean_usage_b = selected_dtype.memory_usage(deep=True).mean()
    mean_usage_mb = mean_usage_b / 1024 ** 2
    print("Average memory usage for {} columns: {:03.2f} MB".format(dtype,mean_usage_mb))
# Out:
# Average memory usage for float64 columns: 0.11 MB
# Average memory usage for int64 columns: 0.14 MB
# Average memory usage for object columns: 1.70 MB

# %% [markdown]
# # Замена пропущенных значений

# %% [markdown]
# Определим количество пропущенных значений по столбцам

# %%
data.isna().sum().to_frame(name = "nans").query("nans > 0")["nans"]
# Out:
# days_employed    2174
# total_income     2174
# Name: nans, dtype: int64

# %% [markdown]
# Заменим пропущенные значения в признаке total_income - ежемесячный доход. Заменим пропущенные значения медианным значением

# %%
data = data.sort_values(by = 'total_income', ascending = True)

# %%
data = data.fillna({'total_income': data.total_income.median()})
data = data.sort_index(ascending = True)
data.isna().sum().to_frame(name = "nans").query("nans > 0")["nans"]
# Out:
# days_employed    2174
# Name: nans, dtype: int64

# %% [markdown]
# Проверим, сколько строк в датафрейме имею корректное значение в признаке days_employed. Примем значение корректным находящееся в диапазоне от 0 до 30000 дней.

# %%
((data.days_employed > 0) & (data.days_employed < 30000)).value_counts()
# Out:
# False    21525
# Name: days_employed, dtype: int64

# %% [markdown]
# Видим, что данное условие не выполняется ни для одной строки датафрейма. Чтобы избежать ошибочной трактовки и в связи с тем, что в параметре days_employed нет необходимости для выполнения задания, удалим данный параметр из датафрейма.

# %%
del data['days_employed']

# %% [markdown]
# # Преобразование типов данных

# %% [markdown]
# С целью сокращения потребления памяти и повышения удобства анализа заменим вещественный тип данных на целочисленный в параметре total_income

# %%
data['total_income'] = data['total_income'].astype(np.int64)

# %% [markdown]
# # Удаление дубликатов

# %% [markdown]
# В датафрейме было найдено 54 дубликата. Все они были удалены с помощью функции drop_duplicates().

# %% [markdown]
# Дубликаты могут появляться из-за ошибок ввода.

# %%
data.duplicated().sum()
# Out:
# 54

# %%
data[data.duplicated()]
# Out:
#        children  dob_years education  education_id          family_status  \
# 2849          0         41   среднее             1        женат / замужем
# 4182          1         34    ВЫСШЕЕ             0       гражданский брак
# 4851          0         60   среднее             1       гражданский брак
# 5557          0         58   среднее             1       гражданский брак
# 7808          0         57   среднее             1       гражданский брак
# 8583          0         58    высшее             0  Не женат / не замужем
# 9238          2         34   среднее             1        женат / замужем
# 9528          0         66   среднее             1         вдовец / вдова
# 9627          0         56   среднее             1        женат / замужем
# 10462         0         62   среднее             1        женат / замужем
# 10697         0         40   среднее             1       гражданский брак
# 10864         0         62   среднее             1        женат / замужем
# 10994         0         62   среднее             1        женат / замужем
# 11791         0         47   среднее             1        женат / замужем
# 12373         0         58   среднее             1        женат / замужем
# 12375         1         37   среднее             1        женат / замужем
# 12736         0         59   среднее             1        женат / замужем
# 13025         1         44   среднее             1        женат / замужем
# 13639         0         64   среднее             1        женат / замужем
# 13773         0         35   среднее             1       гражданский брак
# 13878         1         31   среднее             1        женат / замужем
# 13942         0         44   среднее             1        женат / замужем
# 14432         2         36    высшее             0        женат / замужем
# 14832         0         50   среднее             1  Не женат / не замужем
# 15091         0         58   среднее             1       гражданский брак
# 15188         0         60   среднее             1        женат / замужем
# 15273         0         57   среднее             1       гражданский брак
# 16176         0         47   среднее             1        женат / замужем
# 16378         0         46   среднее             1        женат / замужем
# 16902         2         39   среднее             1       гражданский брак
# 16904         1         32    высшее             0        женат / замужем
# 17379         0         54    высшее             0        женат / замужем
# 17755         1         43   среднее             1        женат / замужем
# 17774         1         40   среднее             1       гражданский брак
# 18328         0         29    высшее             0        женат / замужем
# 18349         1         30    высшее             0        женат / замужем
# 18428         0         64   среднее             1        женат / замужем
# 18521         0         56   среднее             1       гражданский брак
# 18563         0         54   среднее             1        женат / замужем
# 18755         0         58   среднее             1        женат / замужем
# 19041         0         56   среднее             1       гражданский брак
# 19184         0         46   среднее             1        женат / замужем
# 19321         0         23   среднее             1  Не женат / не замужем
# 19387         0         38    высшее             0       гражданский брак
# 19688         0         61   среднее             1        женат / замужем
# 19832         0         48   среднее             1        женат / замужем
# 19946         0         57   среднее             1        женат / замужем
# 20116         0         57   среднее             1       гражданский брак
# 20165         0         42   среднее             1        женат / замужем
# 20702         0         64   среднее             1        женат / замужем
# 21032         0         60   среднее             1        женат / замужем
# 21132         0         47   среднее             1        женат / замужем
# 21281         1         30    высшее             0        женат / замужем
# 21415         0         54   среднее             1        женат / замужем
#
#        family_status_id gender  income_type  debt  total_income  \
# 2849                  0      F    сотрудник     0        145017
# 4182                  1      F    сотрудник     0        145017
# 4851                  1      F    пенсионер     0        145017
# 5557                  1      F    пенсионер     0        145017
# 7808                  1      F    пенсионер     0        145017
# 8583                  4      F    пенсионер     0        145017
# 9238                  0      F    сотрудник     0        145017
# 9528                  2      F    пенсионер     0        145017
# 9627                  0      F    пенсионер     0        145017
# 10462                 0      F    пенсионер     0        145017
# 10697                 1      F    компаньон     0        145017
# 10864                 0      F    пенсионер     0        145017
# 10994                 0      F    пенсионер     0        145017
# 11791                 0      F    сотрудник     0        145017
# 12373                 0      M    сотрудник     0        145017
# 12375                 0      F    сотрудник     0        145017
# 12736                 0      F    пенсионер     0        145017
# 13025                 0      F    сотрудник     0        145017
# 13639                 0      F    пенсионер     0        145017
# 13773                 1      F    сотрудник     0        145017
# 13878                 0      F    компаньон     0        145017
# 13942                 0      F    сотрудник     0        145017
# 14432                 0      F  госслужащий     0        145017
# 14832                 4      F    сотрудник     0        145017
# 15091                 1      M    сотрудник     0        145017
# 15188                 0      M    сотрудник     0        145017
# 15273                 1      F    пенсионер     0        145017
# 16176                 0      F    сотрудник     0        145017
# 16378                 0      F    сотрудник     0        145017
# 16902                 1      F    сотрудник     0        145017
# 16904                 0      F    сотрудник     0        145017
# 17379                 0      M    компаньон     0        145017
# 17755                 0      M    сотрудник     0        145017
# 17774                 1      F    компаньон     0        145017
# 18328                 0      M    сотрудник     0        145017
# 18349                 0      F  госслужащий     0        145017
# 18428                 0      F    пенсионер     0        145017
# 18521                 1      F    сотрудник     0        145017
# 18563                 0      F    сотрудник     0        145017
# 18755                 0      F    пенсионер     0        145017
# 19041                 1      F    сотрудник     0        145017
# 19184                 0      F    сотрудник     0        145017
# 19321                 4      F    сотрудник     0        145017
# 19387                 1      F    компаньон     0        145017
# 19688                 0      F    пенсионер     0        145017
# 19832                 0      F    сотрудник     0        145017
# 19946                 0      F    сотрудник     0        145017
# 20116                 1      M    пенсионер     0        145017
# 20165                 0      F    сотрудник     0        145017
# 20702                 0      F    пенсионер     0        145017
# 21032                 0      F    пенсионер     0        145017
# 21132                 0      F    сотрудник     0        145017
# 21281                 0      F    сотрудник     0        145017
# 21415                 0      F    пенсионер     0        145017
#
#                                      purpose
# 2849                 покупка жилья для семьи
# 4182                                 свадьба
# 4851                                 свадьба
# 5557                         сыграть свадьбу
# 7808                   на проведение свадьбы
# 8583              дополнительное образование
# 9238                 покупка жилья для сдачи
# 9528         операции со своей недвижимостью
# 9627         операции со своей недвижимостью
# 10462      покупка коммерческой недвижимости
# 10697                        сыграть свадьбу
# 10864                           ремонт жилью
# 10994                           ремонт жилью
# 11791             строительство недвижимости
# 12373                   покупка недвижимости
# 12375                   покупка недвижимости
# 12736                  заняться образованием
# 13025       сделка с подержанным автомобилем
# 13639                             автомобиль
# 13773                        сыграть свадьбу
# 13878                          покупка жилья
# 13942                приобретение автомобиля
# 14432                  получение образования
# 14832                           недвижимость
# 15091                  на проведение свадьбы
# 15188                   покупка недвижимости
# 15273                                свадьба
# 16176                           ремонт жилью
# 16378                     высшее образование
# 16902                        сыграть свадьбу
# 16904     на покупку подержанного автомобиля
# 17379  операции с коммерческой недвижимостью
# 17755                  заняться образованием
# 17774       строительство жилой недвижимости
# 18328             покупка жилой недвижимости
# 18349                покупка жилья для семьи
# 18428                                  жилье
# 18521                        сыграть свадьбу
# 18563        операции со своей недвижимостью
# 18755                  заняться образованием
# 19041                  на проведение свадьбы
# 19184                        свой автомобиль
# 19321       сделка с подержанным автомобилем
# 19387                  на проведение свадьбы
# 19688               операции с недвижимостью
# 19832                           ремонт жилью
# 19946       сделка с подержанным автомобилем
# 20116                                свадьба
# 20165                покупка жилья для семьи
# 20702             дополнительное образование
# 21032                  заняться образованием
# 21132                           ремонт жилью
# 21281      покупка коммерческой недвижимости
# 21415                      операции с жильем

# %%
data = data.drop_duplicates()

# %%
data
# Out:
#        children  dob_years            education  education_id  \
# 0             1         42               высшее             0
# 1             1         36              среднее             1
# 2             0         33              Среднее             1
# 3             3         32              среднее             1
# 4             0         53              среднее             1
# 5             0         27               высшее             0
# 6             0         43               высшее             0
# 7             0         50              СРЕДНЕЕ             1
# 8             2         35               ВЫСШЕЕ             0
# 9             0         41              среднее             1
# 10            2         36               высшее             0
# 11            0         40              среднее             1
# 12            0         65              среднее             1
# 13            0         54  неоконченное высшее             2
# 14            0         56               высшее             0
# 15            1         26              среднее             1
# 16            0         35              среднее             1
# 17            0         33               высшее             0
# 18            0         53              среднее             1
# 19            0         48              СРЕДНЕЕ             1
# 20            1         36              среднее             1
# 21            1         33              среднее             1
# 22            1         24              среднее             1
# 23            0         21               высшее             0
# 24            1         57              среднее             1
# 25            0         67              среднее             1
# 26            0         41              среднее             1
# 27            0         28               высшее             0
# 28            1         26               высшее             0
# 29            0         63              среднее             1
# ...         ...        ...                  ...           ...
# 21495         1         50              среднее             1
# 21496         1         31              среднее             1
# 21497         0         48               ВЫСШЕЕ             0
# 21498         1         32              среднее             1
# 21499         0         57              среднее             1
# 21500         0         26  неоконченное высшее             2
# 21501         0         57              среднее             1
# 21502         1         42              среднее             1
# 21503         0         58              среднее             1
# 21504         0         68              среднее             1
# 21505         0         53              среднее             1
# 21506         1         33               ВЫСШЕЕ             0
# 21507         1         32              среднее             1
# 21508         0         62              среднее             1
# 21509         0         59               высшее             0
# 21510         2         28              среднее             1
# 21511         0         29               высшее             0
# 21512         0         26               высшее             0
# 21513         0         35              среднее             1
# 21514         0         27  неоконченное высшее             2
# 21515         1         28              среднее             1
# 21516         0         42               высшее             0
# 21517         0         42               высшее             0
# 21518         0         59              СРЕДНЕЕ             1
# 21519         1         37       ученая степень             4
# 21520         1         43              среднее             1
# 21521         0         67              среднее             1
# 21522         1         38              среднее             1
# 21523         3         38              среднее             1
# 21524         2         40              среднее             1
#
#                family_status  family_status_id gender  income_type  debt  \
# 0            женат / замужем                 0      F    сотрудник     0
# 1            женат / замужем                 0      F    сотрудник     0
# 2            женат / замужем                 0      M    сотрудник     0
# 3            женат / замужем                 0      M    сотрудник     0
# 4           гражданский брак                 1      F    пенсионер     0
# 5           гражданский брак                 1      M    компаньон     0
# 6            женат / замужем                 0      F    компаньон     0
# 7            женат / замужем                 0      M    сотрудник     0
# 8           гражданский брак                 1      F    сотрудник     0
# 9            женат / замужем                 0      M    сотрудник     0
# 10           женат / замужем                 0      M    компаньон     0
# 11           женат / замужем                 0      F    сотрудник     0
# 12          гражданский брак                 1      M    пенсионер     0
# 13           женат / замужем                 0      F    сотрудник     0
# 14          гражданский брак                 1      F    компаньон     1
# 15           женат / замужем                 0      F    сотрудник     0
# 16           женат / замужем                 0      F    сотрудник     0
# 17          гражданский брак                 1      M    сотрудник     0
# 18            вдовец / вдова                 2      F    пенсионер     0
# 19                 в разводе                 3      F    сотрудник     0
# 20           женат / замужем                 0      M    сотрудник     0
# 21          гражданский брак                 1      F    сотрудник     0
# 22          гражданский брак                 1      F    сотрудник     0
# 23          гражданский брак                 1      M    сотрудник     0
# 24     Не женат / не замужем                 4      F    пенсионер     0
# 25           женат / замужем                 0      M    пенсионер     0
# 26           женат / замужем                 0      M  госслужащий     0
# 27           женат / замужем                 0      M    сотрудник     0
# 28           женат / замужем                 0      F    сотрудник     0
# 29     Не женат / не замужем                 4      F    пенсионер     0
# ...                      ...               ...    ...          ...   ...
# 21495       гражданский брак                 1      F    сотрудник     0
# 21496        женат / замужем                 0      F    сотрудник     0
# 21497        женат / замужем                 0      F    компаньон     0
# 21498       гражданский брак                 1      M    сотрудник     0
# 21499       гражданский брак                 1      M    компаньон     0
# 21500  Не женат / не замужем                 4      M    компаньон     0
# 21501        женат / замужем                 0      F    пенсионер     0
# 21502        женат / замужем                 0      F    сотрудник     0
# 21503        женат / замужем                 0      F    сотрудник     0
# 21504        женат / замужем                 0      F    пенсионер     0
# 21505       гражданский брак                 1      M    пенсионер     0
# 21506       гражданский брак                 1      F    сотрудник     0
# 21507       гражданский брак                 1      F  госслужащий     0
# 21508        женат / замужем                 0      M    пенсионер     0
# 21509        женат / замужем                 0      M    пенсионер     0
# 21510        женат / замужем                 0      F    сотрудник     0
# 21511       гражданский брак                 1      F    сотрудник     1
# 21512  Не женат / не замужем                 4      M    компаньон     0
# 21513        женат / замужем                 0      F    сотрудник     0
# 21514  Не женат / не замужем                 4      M    компаньон     0
# 21515        женат / замужем                 0      F    сотрудник     1
# 21516        женат / замужем                 0      F    компаньон     0
# 21517       гражданский брак                 1      F    компаньон     0
# 21518        женат / замужем                 0      F    пенсионер     0
# 21519              в разводе                 3      M    сотрудник     0
# 21520       гражданский брак                 1      F    компаньон     0
# 21521        женат / замужем                 0      F    пенсионер     0
# 21522       гражданский брак                 1      M    сотрудник     1
# 21523        женат / замужем                 0      M    сотрудник     1
# 21524        женат / замужем                 0      F    сотрудник     0
#
#        total_income                                 purpose
# 0            253875                           покупка жилья
# 1            112080                 приобретение автомобиля
# 2            145885                           покупка жилья
# 3            267628              дополнительное образование
# 4            158616                         сыграть свадьбу
# 5            255763                           покупка жилья
# 6            240525                       операции с жильем
# 7            135823                             образование
# 8             95856                   на проведение свадьбы
# 9            144425                 покупка жилья для семьи
# 10           113943                    покупка недвижимости
# 11            77069       покупка коммерческой недвижимости
# 12           145017                         сыграть свадьбу
# 13           130458                 приобретение автомобиля
# 14           165127              покупка жилой недвижимости
# 15           116820  строительство собственной недвижимости
# 16           289202                            недвижимость
# 17            90410              строительство недвижимости
# 18            56823      на покупку подержанного автомобиля
# 19           242831            на покупку своего автомобиля
# 20           209552                            недвижимость
# 21           131812                 приобретение автомобиля
# 22           149681      на покупку подержанного автомобиля
# 23           128265                         сыграть свадьбу
# 24           290547   операции с коммерческой недвижимостью
# 25            55112                    покупка недвижимости
# 26           145017                             образование
# 27           308848  строительство собственной недвижимости
# 28           187863  строительство собственной недвижимости
# 29           145017        строительство жилой недвижимости
# ...             ...                                     ...
# 21495        145017                                 свадьба
# 21496        119392                   на покупку автомобиля
# 21497        145017              строительство недвижимости
# 21498        240767                         сыграть свадьбу
# 21499        157553                                 свадьба
# 21500         77813   операции с коммерческой недвижимостью
# 21501         86232                                   жилье
# 21502        145017        строительство жилой недвижимости
# 21503        264250                   заняться образованием
# 21504         80566              дополнительное образование
# 21505         75439                         сыграть свадьбу
# 21506        145541                                 свадьба
# 21507         98180        сделка с подержанным автомобилем
# 21508         72638                            недвижимость
# 21509         73029                операции с недвижимостью
# 21510        145017                 приобретение автомобиля
# 21511        140068                 покупка жилья для сдачи
# 21512        147301   получение дополнительного образования
# 21513        250986                           покупка жилья
# 21514        355988              строительство недвижимости
# 21515        109486                   заняться образованием
# 21516        322807                    покупка своего жилья
# 21517        178059            на покупку своего автомобиля
# 21518        153864                    сделка с автомобилем
# 21519        115949       покупка коммерческой недвижимости
# 21520        224791                       операции с жильем
# 21521        155999                    сделка с автомобилем
# 21522         89672                            недвижимость
# 21523        244093            на покупку своего автомобиля
# 21524         82047                   на покупку автомобиля
#
# [21471 rows x 11 columns]

# %%
data = data.reset_index()

# %%
del data['index']

# %%
data
# Out:
#        children  dob_years            education  education_id  \
# 0             1         42               высшее             0
# 1             1         36              среднее             1
# 2             0         33              Среднее             1
# 3             3         32              среднее             1
# 4             0         53              среднее             1
# 5             0         27               высшее             0
# 6             0         43               высшее             0
# 7             0         50              СРЕДНЕЕ             1
# 8             2         35               ВЫСШЕЕ             0
# 9             0         41              среднее             1
# 10            2         36               высшее             0
# 11            0         40              среднее             1
# 12            0         65              среднее             1
# 13            0         54  неоконченное высшее             2
# 14            0         56               высшее             0
# 15            1         26              среднее             1
# 16            0         35              среднее             1
# 17            0         33               высшее             0
# 18            0         53              среднее             1
# 19            0         48              СРЕДНЕЕ             1
# 20            1         36              среднее             1
# 21            1         33              среднее             1
# 22            1         24              среднее             1
# 23            0         21               высшее             0
# 24            1         57              среднее             1
# 25            0         67              среднее             1
# 26            0         41              среднее             1
# 27            0         28               высшее             0
# 28            1         26               высшее             0
# 29            0         63              среднее             1
# ...         ...        ...                  ...           ...
# 21441         1         50              среднее             1
# 21442         1         31              среднее             1
# 21443         0         48               ВЫСШЕЕ             0
# 21444         1         32              среднее             1
# 21445         0         57              среднее             1
# 21446         0         26  неоконченное высшее             2
# 21447         0         57              среднее             1
# 21448         1         42              среднее             1
# 21449         0         58              среднее             1
# 21450         0         68              среднее             1
# 21451         0         53              среднее             1
# 21452         1         33               ВЫСШЕЕ             0
# 21453         1         32              среднее             1
# 21454         0         62              среднее             1
# 21455         0         59               высшее             0
# 21456         2         28              среднее             1
# 21457         0         29               высшее             0
# 21458         0         26               высшее             0
# 21459         0         35              среднее             1
# 21460         0         27  неоконченное высшее             2
# 21461         1         28              среднее             1
# 21462         0         42               высшее             0
# 21463         0         42               высшее             0
# 21464         0         59              СРЕДНЕЕ             1
# 21465         1         37       ученая степень             4
# 21466         1         43              среднее             1
# 21467         0         67              среднее             1
# 21468         1         38              среднее             1
# 21469         3         38              среднее             1
# 21470         2         40              среднее             1
#
#                family_status  family_status_id gender  income_type  debt  \
# 0            женат / замужем                 0      F    сотрудник     0
# 1            женат / замужем                 0      F    сотрудник     0
# 2            женат / замужем                 0      M    сотрудник     0
# 3            женат / замужем                 0      M    сотрудник     0
# 4           гражданский брак                 1      F    пенсионер     0
# 5           гражданский брак                 1      M    компаньон     0
# 6            женат / замужем                 0      F    компаньон     0
# 7            женат / замужем                 0      M    сотрудник     0
# 8           гражданский брак                 1      F    сотрудник     0
# 9            женат / замужем                 0      M    сотрудник     0
# 10           женат / замужем                 0      M    компаньон     0
# 11           женат / замужем                 0      F    сотрудник     0
# 12          гражданский брак                 1      M    пенсионер     0
# 13           женат / замужем                 0      F    сотрудник     0
# 14          гражданский брак                 1      F    компаньон     1
# 15           женат / замужем                 0      F    сотрудник     0
# 16           женат / замужем                 0      F    сотрудник     0
# 17          гражданский брак                 1      M    сотрудник     0
# 18            вдовец / вдова                 2      F    пенсионер     0
# 19                 в разводе                 3      F    сотрудник     0
# 20           женат / замужем                 0      M    сотрудник     0
# 21          гражданский брак                 1      F    сотрудник     0
# 22          гражданский брак                 1      F    сотрудник     0
# 23          гражданский брак                 1      M    сотрудник     0
# 24     Не женат / не замужем                 4      F    пенсионер     0
# 25           женат / замужем                 0      M    пенсионер     0
# 26           женат / замужем                 0      M  госслужащий     0
# 27           женат / замужем                 0      M    сотрудник     0
# 28           женат / замужем                 0      F    сотрудник     0
# 29     Не женат / не замужем                 4      F    пенсионер     0
# ...                      ...               ...    ...          ...   ...
# 21441       гражданский брак                 1      F    сотрудник     0
# 21442        женат / замужем                 0      F    сотрудник     0
# 21443        женат / замужем                 0      F    компаньон     0
# 21444       гражданский брак                 1      M    сотрудник     0
# 21445       гражданский брак                 1      M    компаньон     0
# 21446  Не женат / не замужем                 4      M    компаньон     0
# 21447        женат / замужем                 0      F    пенсионер     0
# 21448        женат / замужем                 0      F    сотрудник     0
# 21449        женат / замужем                 0      F    сотрудник     0
# 21450        женат / замужем                 0      F    пенсионер     0
# 21451       гражданский брак                 1      M    пенсионер     0
# 21452       гражданский брак                 1      F    сотрудник     0
# 21453       гражданский брак                 1      F  госслужащий     0
# 21454        женат / замужем                 0      M    пенсионер     0
# 21455        женат / замужем                 0      M    пенсионер     0
# 21456        женат / замужем                 0      F    сотрудник     0
# 21457       гражданский брак                 1      F    сотрудник     1
# 21458  Не женат / не замужем                 4      M    компаньон     0
# 21459        женат / замужем                 0      F    сотрудник     0
# 21460  Не женат / не замужем                 4      M    компаньон     0
# 21461        женат / замужем                 0      F    сотрудник     1
# 21462        женат / замужем                 0      F    компаньон     0
# 21463       гражданский брак                 1      F    компаньон     0
# 21464        женат / замужем                 0      F    пенсионер     0
# 21465              в разводе                 3      M    сотрудник     0
# 21466       гражданский брак                 1      F    компаньон     0
# 21467        женат / замужем                 0      F    пенсионер     0
# 21468       гражданский брак                 1      M    сотрудник     1
# 21469        женат / замужем                 0      M    сотрудник     1
# 21470        женат / замужем                 0      F    сотрудник     0
#
#        total_income                                 purpose
# 0            253875                           покупка жилья
# 1            112080                 приобретение автомобиля
# 2            145885                           покупка жилья
# 3            267628              дополнительное образование
# 4            158616                         сыграть свадьбу
# 5            255763                           покупка жилья
# 6            240525                       операции с жильем
# 7            135823                             образование
# 8             95856                   на проведение свадьбы
# 9            144425                 покупка жилья для семьи
# 10           113943                    покупка недвижимости
# 11            77069       покупка коммерческой недвижимости
# 12           145017                         сыграть свадьбу
# 13           130458                 приобретение автомобиля
# 14           165127              покупка жилой недвижимости
# 15           116820  строительство собственной недвижимости
# 16           289202                            недвижимость
# 17            90410              строительство недвижимости
# 18            56823      на покупку подержанного автомобиля
# 19           242831            на покупку своего автомобиля
# 20           209552                            недвижимость
# 21           131812                 приобретение автомобиля
# 22           149681      на покупку подержанного автомобиля
# 23           128265                         сыграть свадьбу
# 24           290547   операции с коммерческой недвижимостью
# 25            55112                    покупка недвижимости
# 26           145017                             образование
# 27           308848  строительство собственной недвижимости
# 28           187863  строительство собственной недвижимости
# 29           145017        строительство жилой недвижимости
# ...             ...                                     ...
# 21441        145017                                 свадьба
# 21442        119392                   на покупку автомобиля
# 21443        145017              строительство недвижимости
# 21444        240767                         сыграть свадьбу
# 21445        157553                                 свадьба
# 21446         77813   операции с коммерческой недвижимостью
# 21447         86232                                   жилье
# 21448        145017        строительство жилой недвижимости
# 21449        264250                   заняться образованием
# 21450         80566              дополнительное образование
# 21451         75439                         сыграть свадьбу
# 21452        145541                                 свадьба
# 21453         98180        сделка с подержанным автомобилем
# 21454         72638                            недвижимость
# 21455         73029                операции с недвижимостью
# 21456        145017                 приобретение автомобиля
# 21457        140068                 покупка жилья для сдачи
# 21458        147301   получение дополнительного образования
# 21459        250986                           покупка жилья
# 21460        355988              строительство недвижимости
# 21461        109486                   заняться образованием
# 21462        322807                    покупка своего жилья
# 21463        178059            на покупку своего автомобиля
# 21464        153864                    сделка с автомобилем
# 21465        115949       покупка коммерческой недвижимости
# 21466        224791                       операции с жильем
# 21467        155999                    сделка с автомобилем
# 21468         89672                            недвижимость
# 21469        244093            на покупку своего автомобиля
# 21470         82047                   на покупку автомобиля
#
# [21471 rows x 11 columns]

# %% [markdown]
# # Категоризация данных

# %% [markdown]
# Необходимо разделить людей на категории по возрасту.

# %% [markdown]
# Категоризация для признака "dob_years":
# 0 - 18-24 года (период, который большинство посвящают получению образования);
# 1 - 25-35 лет (период создания семей);
# 2 - 36-50 лет (период воспитания и содержания детей);
# 3 - >51 года (период активных трат на здоровье).

# %% [markdown]
# Пропущенным значениям, заполненным, как 0, придадим категорию "-1". Впоследствии обработаем их и заполним.

# %%
a = data['dob_years']
a = np.where(a <= 17, -1, a)
a = np.where((a > 17) & (a < 25), 0, a)
a = np.where((a > 24) & (a < 36), 1, a)
a = np.where((a > 35) & (a < 51), 2, a)
a = np.where(a > 50, 3, a)
data = data.assign(dob_years = a)
data['dob_years'].value_counts()
# Out:
#  2    8130
#  3    6655
#  1    5709
#  0     876
# -1     101
# Name: dob_years, dtype: int64

# %% [markdown]
# Колонки "education" и "family_status" предлагается удалить, так как колонки "education_id", "family_status_id" несут ту же информацию.

# %% [markdown]
# Для того, чтобы была возможность понять смысл колонок "education_id", "family_status_id", составляются словари.

# %% [markdown]
# Для "education_id":
# 0 - высшее;
# 1 - среднее;
# 2 - неоконченное высшее;
# 3 - начальное;
# 4 - ученая степень.

# %% [markdown]
# Для "family_status_id":
# 0 - женат / замужем;
# 1 - гражданский брак;
# 2 - вдовец / вдова;
# 3 - в разводе;
# 4 - не женат / не замужем.

# %% [markdown]
# Для "income_type" некоторые категории необходимо объединить, так как "студент" является аналогом "безработный", "предприниматель" - аналог "компаньон", "в декрете" - аналог "сотрудник", заменить на числовые значения, так как тип int занимает меньше памяти по сравнению с object, и с данным типом данных проще работать при анализе.

# %% [markdown]
# Словарь для "income_type":
# 0 - сотрудник;
# 1 - компаньон;
# 2 - пенсионер;
# 3 - госслужащий;
# 4 - безработный.

# %%
d_1 = data.drop(['education', 'family_status'], axis = 1)

# %%
a = d_1['income_type'].replace('предприниматель', 'компаньон') \
    .replace('в декрете', 'сотрудник') \
    .replace('студент', 'безработный')
d_1 = d_1.assign(income_type = a)
d_1['income_type'].value_counts()
# Out:
# сотрудник      11092
# компаньон       5082
# пенсионер       3837
# госслужащий     1457
# безработный        3
# Name: income_type, dtype: int64

# %%
dict_1 = {'сотрудник': 0, 'компаньон': 1, 'пенсионер': 2, 'госслужащий': 3, 'безработный': 4}
d_1 = d_1.replace({"income_type": dict_1})
d_1['income_type'].value_counts()
# Out:
# 0    11092
# 1     5082
# 2     3837
# 3     1457
# 4        3
# Name: income_type, dtype: int64

# %% [markdown]
# Значение признака "gender" также заменим числовыми: 0 - female; 1 - male. XNA заменим, как -1, так как ошибочное значение. Впоследствии, необходимо будет определить к какой категории ближе данный элемент.

# %%
d_1['gender'].value_counts()
# Out:
# F      14189
# M       7281
# XNA        1
# Name: gender, dtype: int64

# %%
d_1['gender'] = d_1['gender'].replace('F', 0) \
    .replace('M', 1) \
    .replace('XNA', -1)

# %% [markdown]
# Необходимо категоризовать признак (total_income). Для этого разбили значения на перцентили. Необходимо будет проверить, на сколько такие категории являются показательными

# %% [markdown]
# Словарь:
# 0 - <=98554;
# 1 - 98554-135514;
# 2 - 135514-156400;
# 3 - 156400-214546;
# 4 - > 214546.

# %%
d_2 = d_1.copy(deep=True)
d_2.head()
# Out:
#    children  dob_years  education_id  family_status_id  gender  income_type  \
# 0         1          2             0                 0       0            0
# 1         1          2             1                 0       0            0
# 2         0          1             1                 0       1            0
# 3         3          1             1                 0       1            0
# 4         0          3             1                 1       0            2
#
#    debt  total_income                     purpose
# 0     0        253875               покупка жилья
# 1     0        112080     приобретение автомобиля
# 2     0        145885               покупка жилья
# 3     0        267628  дополнительное образование
# 4     0        158616             сыграть свадьбу

# %%
d_2 = d_2.query("total_income != 0")
np.percentile(d_2['total_income'], q = [20, 40, 60, 80])
# Out:
# array([ 98554., 135514., 156400., 214546.])

# %%
n = d_1['total_income']
n = np.where((n > 0) & (n < 98554), 0, n)
n = np.where((n >= 98554) & (n < 135514), 1, n)
n = np.where((n >= 135514) & (n < 156400), 2, n)
n = np.where((n >= 156400) & (n < 214546), 3, n)
n = np.where(n >= 214546, 4, n)
d_1 = d_1.assign(total_income = n)
d_1['total_income'].value_counts()
# Out:
# 4    4295
# 3    4294
# 2    4294
# 1    4294
# 0    4294
# Name: total_income, dtype: int64

# %% [markdown]
# Для того, чтобы категоризовать признак "purpose", необходимо провести лемматизацию и выделить основные категории.

# %%
d_1['purpose'].value_counts()
# Out:
# свадьба                                   793
# на проведение свадьбы                     773
# сыграть свадьбу                           769
# операции с недвижимостью                  675
# покупка коммерческой недвижимости         662
# операции с жильем                         652
# покупка жилья для сдачи                   652
# операции с коммерческой недвижимостью     650
# жилье                                     646
# покупка жилья                             646
# покупка жилья для семьи                   638
# строительство собственной недвижимости    635
# недвижимость                              633
# операции со своей недвижимостью           627
# строительство жилой недвижимости          625
# покупка недвижимости                      621
# покупка своего жилья                      620
# строительство недвижимости                619
# ремонт жилью                              607
# покупка жилой недвижимости                606
# на покупку своего автомобиля              505
# заняться высшим образованием              496
# автомобиль                                494
# сделка с подержанным автомобилем          486
# свой автомобиль                           479
# автомобили                                478
# на покупку подержанного автомобиля        478
# на покупку автомобиля                     472
# приобретение автомобиля                   461
# дополнительное образование                460
# сделка с автомобилем                      455
# высшее образование                        452
# получение дополнительного образования     447
# образование                               447
# получение образования                     442
# профильное образование                    436
# получение высшего образования             426
# заняться образованием                     408
# Name: purpose, dtype: int64

# %%
m = Mystem()

# %% [markdown]
# Находим леммы среди целей получения кредита

# %%
purpose_list = d_1['purpose']
purpose_list = purpose_list.to_string()
purpose_list = str(purpose_list)
for i in range(21470): 
    purpose_list = purpose_list.replace('\n' + str(i + 1) + ' ', '')
purpose_list = re.sub(r'\s+', ' ', purpose_list)
purpose_list = purpose_list.replace('0 ', '') \
    .replace(' Name: purpose, Length: 21471, dtype: object', '')
lemm = m.lemmatize(purpose_list)

# %% [markdown]
# Выводим леммы и частоту их встречания, удаляем несодержательные леммы

# %%
lemm = [a for a in lemm if a != ' ']
lemm = [a for a in lemm if a != 'покупка']
lemm = [a for a in lemm if a != 'приобретение'] 
lemm = [a for a in lemm if a != 'дополнительный']
lemm = [a for a in lemm if a != 'сыграть']
lemm = [a for a in lemm if a != 'с']
lemm = [a for a in lemm if a != 'для'] 
lemm = [a for a in lemm if a != 'коммерческий']
lemm = [a for a in lemm if a != 'собственный']
lemm = [a for a in lemm if a != 'подержать']
lemm = [a for a in lemm if a != 'свой']
lemm = [a for a in lemm if a != 'со'] 
lemm = [a for a in lemm if a != 'заниматься']
lemm = [a for a in lemm if a != 'получение']
lemm = [a for a in lemm if a != 'высокий']
lemm = [a for a in lemm if a != 'подержанный'] 
lemm = [a for a in lemm if a != 'профильный']
lemm = [a for a in lemm if a != 'сдача'] 
lemm = [a for a in lemm if a != '\n']
lemm = [a for a in lemm if a != 'на']
lemm = [a for a in lemm if a != 'проведение']
lemm = [a for a in lemm if a != 'жилой']

counter = Counter(lemm)
counter
# Out:
# Counter({'жилье': 4461,
#          'автомобиль': 4308,
#          'образование': 4014,
#          'свадьба': 2335,
#          'операция': 2604,
#          'семья': 638,
#          'недвижимость': 6353,
#          'строительство': 1879,
#          'сделка': 941,
#          'ремонт': 607})

# %% [markdown]
# Видим, что основными целями являются "недвижимость", "автомобиль", "образование", "свадьба". Необходимо проверить оставшиеся леммы, в каком значении они употребялются

# %% [markdown]
# Леммы "операция", "семья", "ремонт" относятся к категории "недвижимость". Лемма "сделка" относится к категории "автомобиль".

# %%
m = d_1[d_1['purpose'].str.contains("операц")]
m.purpose.unique()
# Out:
# array(['операции с жильем', 'операции с коммерческой недвижимостью',
#        'операции со своей недвижимостью', 'операции с недвижимостью'],
#       dtype=object)

# %%
m = d_1[d_1['purpose'].str.contains("семь")]
m.purpose.unique()
# Out:
# array(['покупка жилья для семьи'], dtype=object)

# %%
m = d_1[d_1['purpose'].str.contains("сделк")]
m.purpose.unique()
# Out:
# array(['сделка с подержанным автомобилем', 'сделка с автомобилем'],
#       dtype=object)

# %%
m = d_1[d_1['purpose'].str.contains("ремонт")]
m.purpose.unique()
# Out:
# array(['ремонт жилью'], dtype=object)

# %% [markdown]
# Заменим столбец "purpose" леммами, которые будут являться категориями целей получения кредита.

# %%
d_1.loc[d_1['purpose'].str.contains("авто"), 'purpose'] = 'автомобиль'
d_1.loc[d_1['purpose'].str.contains("жил"), 'purpose'] = 'недвижимость'
d_1.loc[d_1['purpose'].str.contains("недвиж"), 'purpose'] = 'недвижимость'
d_1.loc[d_1['purpose'].str.contains("образов"), 'purpose'] = 'образование'
d_1.loc[d_1['purpose'].str.contains("свад"), 'purpose'] = 'свадьба'

# %%
d_1.purpose.unique()
# Out:
# array(['недвижимость', 'автомобиль', 'образование', 'свадьба'],
#       dtype=object)

# %% [markdown]
# Заменим категориии 'недвижимость', 'автомобиль', 'образование', 'свадьба' на '0', '1', '2', '3'.

# %%
dict_3 = {'недвижимость': 0, 'автомобиль': 1, 'образование': 2, 'свадьба': 3}
d_1 = d_1.replace({"purpose": dict_3})

# %%
d_1
# Out:
#        children  dob_years  education_id  family_status_id  gender  \
# 0             1          2             0                 0       0
# 1             1          2             1                 0       0
# 2             0          1             1                 0       1
# 3             3          1             1                 0       1
# 4             0          3             1                 1       0
# 5             0          1             0                 1       1
# 6             0          2             0                 0       0
# 7             0          2             1                 0       1
# 8             2          1             0                 1       0
# 9             0          2             1                 0       1
# 10            2          2             0                 0       1
# 11            0          2             1                 0       0
# 12            0          3             1                 1       1
# 13            0          3             2                 0       0
# 14            0          3             0                 1       0
# 15            1          1             1                 0       0
# 16            0          1             1                 0       0
# 17            0          1             0                 1       1
# 18            0          3             1                 2       0
# 19            0          2             1                 3       0
# 20            1          2             1                 0       1
# 21            1          1             1                 1       0
# 22            1          0             1                 1       0
# 23            0          0             0                 1       1
# 24            1          3             1                 4       0
# 25            0          3             1                 0       1
# 26            0          2             1                 0       1
# 27            0          1             0                 0       1
# 28            1          1             0                 0       0
# 29            0          3             1                 4       0
# ...         ...        ...           ...               ...     ...
# 21441         1          2             1                 1       0
# 21442         1          1             1                 0       0
# 21443         0          2             0                 0       0
# 21444         1          1             1                 1       1
# 21445         0          3             1                 1       1
# 21446         0          1             2                 4       1
# 21447         0          3             1                 0       0
# 21448         1          2             1                 0       0
# 21449         0          3             1                 0       0
# 21450         0          3             1                 0       0
# 21451         0          3             1                 1       1
# 21452         1          1             0                 1       0
# 21453         1          1             1                 1       0
# 21454         0          3             1                 0       1
# 21455         0          3             0                 0       1
# 21456         2          1             1                 0       0
# 21457         0          1             0                 1       0
# 21458         0          1             0                 4       1
# 21459         0          1             1                 0       0
# 21460         0          1             2                 4       1
# 21461         1          1             1                 0       0
# 21462         0          2             0                 0       0
# 21463         0          2             0                 1       0
# 21464         0          3             1                 0       0
# 21465         1          2             4                 3       1
# 21466         1          2             1                 1       0
# 21467         0          3             1                 0       0
# 21468         1          2             1                 1       1
# 21469         3          2             1                 0       1
# 21470         2          2             1                 0       0
#
#        income_type  debt  total_income  purpose
# 0                0     0             4        0
# 1                0     0             1        1
# 2                0     0             2        0
# 3                0     0             4        2
# 4                2     0             3        3
# 5                1     0             4        0
# 6                1     0             4        0
# 7                0     0             2        2
# 8                0     0             0        3
# 9                0     0             2        0
# 10               1     0             1        0
# 11               0     0             0        0
# 12               2     0             2        3
# 13               0     0             1        1
# 14               1     1             3        0
# 15               0     0             1        0
# 16               0     0             4        0
# 17               0     0             0        0
# 18               2     0             0        1
# 19               0     0             4        1
# 20               0     0             3        0
# 21               0     0             1        1
# 22               0     0             2        1
# 23               0     0             1        3
# 24               2     0             4        0
# 25               2     0             0        0
# 26               3     0             2        2
# 27               0     0             4        0
# 28               0     0             3        0
# 29               2     0             2        0
# ...            ...   ...           ...      ...
# 21441            0     0             2        3
# 21442            0     0             1        1
# 21443            1     0             2        0
# 21444            0     0             4        3
# 21445            1     0             3        3
# 21446            1     0             0        0
# 21447            2     0             0        0
# 21448            0     0             2        0
# 21449            0     0             4        2
# 21450            2     0             0        2
# 21451            2     0             0        3
# 21452            0     0             2        3
# 21453            3     0             0        1
# 21454            2     0             0        0
# 21455            2     0             0        0
# 21456            0     0             2        1
# 21457            0     1             2        0
# 21458            1     0             2        2
# 21459            0     0             4        0
# 21460            1     0             4        0
# 21461            0     1             1        2
# 21462            1     0             4        0
# 21463            1     0             3        1
# 21464            2     0             2        1
# 21465            0     0             1        0
# 21466            1     0             4        0
# 21467            2     0             2        1
# 21468            0     1             0        0
# 21469            0     1             4        1
# 21470            0     0             0        1
#
# [21471 rows x 9 columns]

# %% [markdown]
# # Работа с некорректными значениями

# %% [markdown]
# Значения "-1" и "20" в признаке children являются некорректными. Их стоит заменить на ошибочную категорию "-1"

# %%
d_1['children'].value_counts()
# Out:
#  0     14107
#  1      4809
#  2      2052
#  3       330
#  20       76
# -1        47
#  4        41
#  5         9
# Name: children, dtype: int64

# %%
d = d_1['children'].replace(20, -1)
d_1 = d_1.assign(children = d)
d_1['children'].value_counts()
# Out:
#  0    14107
#  1     4809
#  2     2052
#  3      330
# -1      123
#  4       41
#  5        9
# Name: children, dtype: int64

# %% [markdown]
# # Поиск зависимостей

# %% [markdown]
# Есть ли зависимость между наличием детей и возвратом кредита в срок?

# %%
t_1 = d_1.groupby(['children'], as_index = False).aggregate({'debt': 'count'}) \
    .rename(columns = {'debt': 'total'})
t_1
# Out:
#    children  total
# 0        -1    123
# 1         0  14107
# 2         1   4809
# 3         2   2052
# 4         3    330
# 5         4     41
# 6         5      9

# %%
t_2 = d_1.groupby(['children'], as_index = False).aggregate({'debt': 'sum'}) \
    .rename(columns = {'debt': 'amount_of_debts'})
t_2['total'] = t_1['total']
t_2['percent'] = t_2['amount_of_debts'] / t_2['total'] * 100
t_2
# Out:
#    children  amount_of_debts  total   percent
# 0        -1                9    123  7.317073
# 1         0             1063  14107  7.535266
# 2         1              444   4809  9.232689
# 3         2              194   2052  9.454191
# 4         3               27    330  8.181818
# 5         4                4     41  9.756098
# 6         5                0      9  0.000000

# %% [markdown]
# На данной сводной таблице  видно, что зависимости между наличем детей и возвартом кредита в срок нет

# %% [markdown]
# Есть ли зависимость между семейным положением и возвратом кредита в срок?

# %%
t_3 = d_1.groupby(['family_status_id'], as_index = False).aggregate({'debt': 'count'}) \
    .rename(columns = {'debt': 'total'})
t_3
# Out:
#    family_status_id  total
# 0                 0  12344
# 1                 1   4163
# 2                 2    959
# 3                 3   1195
# 4                 4   2810

# %%
t_4 = d_1.groupby(['family_status_id'], as_index = False).aggregate({'debt': 'sum'}) \
    .rename(columns = {'debt': 'amount_of_debts'})
t_4['total'] = t_3['total']
t_4['percent'] = t_4['amount_of_debts'] / t_4['total'] * 100
t_4
# Out:
#    family_status_id  amount_of_debts  total   percent
# 0                 0              931  12344  7.542126
# 1                 1              388   4163  9.320202
# 2                 2               63    959  6.569343
# 3                 3               85   1195  7.112971
# 4                 4              274   2810  9.750890

# %% [markdown]
# На данной сводной таблице  видно, что зависимости между семейным статусом и возвартом кредита в срок нет

# %% [markdown]
# Есть ли зависимость между уровнем дохода и возвратом кредита в срок?

# %%
t_5 = d_1.groupby(['total_income'], as_index = False).aggregate({'debt': 'count'}) \
    .rename(columns = {'debt': 'total'})
t_5
# Out:
#    total_income  total
# 0             0   4294
# 1             1   4294
# 2             2   4294
# 3             3   4294
# 4             4   4295

# %%
t_6 = d_1.groupby(['total_income'], as_index = False).aggregate({'debt': 'sum'}) \
    .rename(columns = {'debt': 'amount_of_debts'})
t_6['total'] = t_5['total']
t_6['percent'] = t_6['amount_of_debts'] / t_6['total'] * 100
t_6
# Out:
#    total_income  amount_of_debts  total   percent
# 0             0              344   4294  8.011178
# 1             1              355   4294  8.267350
# 2             2              370   4294  8.616674
# 3             3              372   4294  8.663251
# 4             4              300   4295  6.984866

# %% [markdown]
# При доходе свыше 214000 рублей задолженностей кредита меньше всего. Но стоит ли считать разницу в 1,5% показательной?

# %% [markdown]
# Как разные цели кредита влияют на его возврат в срок?

# %%
t_7 = d_1.groupby(['purpose']).aggregate({'debt': 'count'}) \
    .rename(columns = {'debt': 'total'})
t_7
# Out:
#          total
# purpose
# 0        10814
# 1         4308
# 2         4014
# 3         2335

# %%
t_8 = d_1.groupby(['purpose'], as_index = False).aggregate({'debt': 'sum'}) \
    .rename(columns = {'debt': 'amount_of_debts'})
t_8['total'] = t_7['total']
t_8['percent'] = t_8['amount_of_debts'] / t_8['total'] * 100
t_8
# Out:
#    purpose  amount_of_debts  total   percent
# 0        0              782  10814  7.231367
# 1        1              403   4308  9.354689
# 2        2              370   4014  9.217738
# 3        3              186   2335  7.965739

# %% [markdown]
# Кредиты, взятые на такие цели, как "автомобиль", "образование", возвращают немного реже

# %% [markdown]
# Среди проведенных исследований зависимостей не было найдено показательных связей.
